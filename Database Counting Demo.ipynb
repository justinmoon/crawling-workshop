# %%
import contextlib
import os
import random
import sqlite3
import threading
import time

i = 0
lock = threading.Lock()

filename = "counting.db"

def execute_statement(statement, args):
    with contextlib.closing(sqlite3.connect(filename)) as conn: # auto-closes
        with conn: # auto-commits
            with contextlib.closing(conn.cursor()) as cursor: # auto-closes
                cursor.execute(statement, args)    
                
def target(worker):
    global i
    while True:
        print(f"top of loop for {worker}")
        # Spread out the work
        time.sleep(random.random())

        # Insert the count
        query = """
        INSERT INTO counting (worker, count)
        VALUES (:worker, :count)
        """
        with lock:
            args = {"worker": worker, "count": 14688121314846993587}
            execute_statement(query, args)
            i += 1


def create_db():
    # Start fresh every time
    try:
        os.remove(filename)
    except:
        pass

    # Create the DB
    db = sqlite3.connect(filename)
    db.execute("CREATE TABLE counting (id INT, worker INT, count INT)")
    
def demo():
    create_db()
    threads = []

    for worker in range(4):
        thread = threading.Thread(target=target, args=(worker,))
        thread.start()
        threads.append(thread)

    for thread in threads:
        # Wait for it to finish (I believe this will make killing easier)
        thread.join()
# Out:
# top of loop for 2
# top of loop for 3
# top of loop for 3
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 3
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 3

# %%
db = sqlite3.connect("counting.db")

db.execute("select * from counting order by count").fetchall()
# Out:
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 1
# [(None, 1, 0),
#  (None, 2, 0),
#  (None, 0, 1),
#  (None, 3, 1),
#  (None, 3, 1),
#  (None, 3, 2),
#  (None, 3, 2),
#  (None, 1, 2),
#  (None, 2, 3),
#  (None, 1, 3),
#  (None, 2, 3),
#  (None, 0, 4),
#  (None, 2, 4),
#  (None, 1, 4),
#  (None, 1, 5),
#  (None, 1, 5),
#  (None, 0, 5),
#  (None, 3, 6),
#  (None, 1, 6),
#  (None, 2, 6),
#  (None, 0, 7),
#  (None, 2, 7),
#  (None, 1, 7),
#  (None, 1, 8),
#  (None, 0, 8),
#  (None, 0, 8),
#  (None, 2, 9),
#  (None, 0, 9),
#  (None, 1, 9),
#  (None, 1, 10),
#  (None, 0, 10),
#  (None, 0, 10),
#  (None, 0, 11),
#  (None, 1, 11),
#  (None, 0, 11),
#  (None, 0, 12),
#  (None, 3, 12),
#  (None, 3, 12),
#  (None, 3, 13),
#  (None, 1, 13),
#  (None, 3, 13),
#  (None, 1, 14),
#  (None, 3, 14),
#  (None, 1, 14),
#  (None, 1, 15),
#  (None, 1, 15),
#  (None, 1, 15),
#  (None, 3, 16),
#  (None, 0, 16),
#  (None, 2, 16),
#  (None, 2, 17),
#  (None, 1, 17),
#  (None, 3, 17),
#  (None, 1, 18),
#  (None, 2, 18),
#  (None, 3, 18),
#  (None, 1, 19),
#  (None, 3, 19),
#  (None, 2, 19),
#  (None, 2, 20),
#  (None, 1, 20),
#  (None, 0, 20),
#  (None, 2, 21),
#  (None, 0, 21),
#  (None, 3, 21),
#  (None, 3, 22),
#  (None, 3, 22),
#  (None, 0, 22),
#  (None, 0, 23),
#  (None, 2, 23),
#  (None, 3, 23),
#  (None, 2, 24),
#  (None, 2, 24),
#  (None, 1, 24),
#  (None, 0, 25),
#  (None, 2, 25),
#  (None, 2, 25),
#  (None, 3, 26),
#  (None, 0, 26),
#  (None, 3, 26),
#  (None, 1, 27),
#  (None, 1, 27),
#  (None, 1, 27),
#  (None, 0, 28),
#  (None, 2, 28),
#  (None, 1, 28),
#  (None, 3, 29),
#  (None, 1, 29),
#  (None, 0, 29),
#  (None, 1, 30),
#  (None, 1, 30),
#  (None, 2, 30),
#  (None, 1, 31),
#  (None, 1, 31),
#  (None, 2, 31),
#  (None, 1, 32),
#  (None, 1, 32),
#  (None, 1, 32),
#  (None, 2, 33),
#  (None, 3, 33),
#  (None, 1, 33),
#  (None, 2, 34),
#  (None, 3, 34),
#  (None, 0, 34),
#  (None, 3, 35),
#  (None, 0, 35),
#  (None, 0, 35),
#  (None, 3, 36),
#  (None, 0, 36),
#  (None, 2, 36),
#  (None, 3, 37),
#  (None, 1, 37),
#  (None, 1, 37),
#  (None, 2, 38),
#  (None, 2, 38),
#  (None, 1, 38),
#  (None, 3, 39),
#  (None, 2, 39),
#  (None, 2, 39),
#  (None, 3, 40),
#  (None, 2, 40),
#  (None, 3, 40),
#  (None, 0, 41),
#  (None, 3, 41),
#  (None, 0, 41),
#  (None, 1, 42),
#  (None, 2, 42),
#  (None, 3, 42),
#  (None, 2, 43),
#  (None, 0, 43),
#  (None, 3, 43),
#  (None, 1, 43),
#  (None, 1, 44),
#  (None, 2, 44),
#  (None, 2, 44),
#  (None, 2, 44),
#  (None, 1, 45),
#  (None, 0, 45),
#  (None, 1, 45),
#  (None, 3, 45),
#  (None, 1, 46),
#  (None, 1, 46),
#  (None, 0, 46),
#  (None, 1, 46),
#  (None, 1, 47),
#  (None, 1, 47),
#  (None, 1, 47),
#  (None, 2, 47),
#  (None, 3, 48),
#  (None, 0, 48),
#  (None, 1, 48),
#  (None, 0, 48),
#  (None, 3, 49),
#  (None, 2, 49),
#  (None, 2, 49),
#  (None, 1, 49),
#  (None, 2, 50),
#  (None, 0, 50),
#  (None, 0, 50),
#  (None, 3, 50),
#  (None, 0, 51),
#  (None, 3, 51),
#  (None, 3, 51),
#  (None, 1, 51),
#  (None, 1, 52),
#  (None, 2, 52),
#  (None, 2, 52),
#  (None, 3, 52),
#  (None, 1, 53),
#  (None, 1, 53),
#  (None, 3, 53),
#  (None, 0, 53),
#  (None, 3, 54),
#  (None, 1, 54),
#  (None, 3, 54),
#  (None, 3, 54),
#  (None, 3, 55),
#  (None, 3, 55),
#  (None, 1, 55),
#  (None, 3, 55),
#  (None, 0, 56),
#  (None, 0, 56),
#  (None, 1, 56),
#  (None, 0, 56),
#  (None, 2, 57),
#  (None, 1, 57),
#  (None, 0, 57),
#  (None, 0, 57),
#  (None, 1, 58),
#  (None, 2, 58),
#  (None, 0, 58),
#  (None, 1, 58),
#  (None, 1, 59),
#  (None, 3, 59),
#  (None, 2, 59),
#  (None, 0, 59),
#  (None, 3, 60),
#  (None, 1, 60),
#  (None, 3, 60),
#  (None, 2, 60),
#  (None, 3, 61),
#  (None, 2, 61),
#  (None, 1, 61),
#  (None, 1, 61),
#  (None, 1, 62),
#  (None, 0, 62),
#  (None, 2, 62),
#  (None, 1, 62),
#  (None, 2, 63),
#  (None, 3, 63),
#  (None, 3, 63),
#  (None, 2, 63),
#  (None, 2, 64),
#  (None, 2, 64),
#  (None, 3, 64),
#  (None, 3, 64),
#  (None, 0, 65),
#  (None, 2, 65),
#  (None, 3, 65),
#  (None, 2, 65),
#  (None, 3, 66),
#  (None, 1, 66),
#  (None, 1, 66),
#  (None, 0, 66),
#  (None, 0, 67),
#  (None, 2, 67),
#  (None, 0, 67),
#  (None, 3, 67),
#  (None, 2, 68),
#  (None, 1, 68),
#  (None, 2, 68),
#  (None, 1, 68),
#  (None, 0, 69),
#  (None, 0, 69),
#  (None, 2, 69),
#  (None, 0, 69),
#  (None, 1, 70),
#  (None, 0, 70),
#  (None, 1, 70),
#  (None, 3, 70),
#  (None, 3, 71),
#  (None, 1, 71),
#  (None, 0, 71),
#  (None, 0, 71),
#  (None, 2, 72),
#  (None, 2, 72),
#  (None, 0, 72),
#  (None, 0, 72),
#  (None, 1, 73),
#  (None, 2, 73),
#  (None, 0, 73),
#  (None, 2, 73),
#  (None, 3, 74),
#  (None, 1, 74),
#  (None, 1, 74),
#  (None, 1, 74),
#  (None, 2, 75),
#  (None, 3, 75),
#  (None, 2, 75),
#  (None, 2, 75),
#  (None, 1, 76),
#  (None, 3, 76),
#  (None, 2, 76),
#  (None, 1, 76),
#  (None, 1, 77),
#  (None, 1, 77),
#  (None, 3, 77),
#  (None, 0, 77),
#  (None, 1, 78),
#  (None, 3, 78),
#  (None, 1, 78),
#  (None, 2, 78),
#  (None, 3, 79),
#  (None, 1, 79),
#  (None, 1, 79),
#  (None, 1, 79),
#  (None, 1, 80),
#  (None, 0, 80),
#  (None, 3, 80),
#  (None, 2, 80),
#  (None, 2, 81),
#  (None, 2, 81),
#  (None, 2, 81),
#  (None, 3, 81),
#  (None, 3, 82),
#  (None, 0, 82),
#  (None, 3, 82),
#  (None, 3, 82),
#  (None, 1, 83),
#  (None, 1, 83),
#  (None, 3, 83),
#  (None, 1, 83),
#  (None, 1, 84),
#  (None, 0, 84),
#  (None, 1, 84),
#  (None, 3, 84),
#  (None, 0, 85),
#  (None, 3, 85),
#  (None, 1, 85),
#  (None, 0, 85),
#  (None, 3, 86),
#  (None, 3, 86),
#  (None, 2, 86),
#  (None, 1, 86),
#  (None, 3, 87),
#  (None, 1, 87),
#  (None, 0, 87),
#  (None, 0, 87),
#  (None, 2, 88),
#  (None, 2, 88),
#  (None, 0, 88),
#  (None, 2, 88),
#  (None, 0, 89),
#  (None, 3, 89),
#  (None, 3, 89),
#  (None, 1, 89),
#  (None, 1, 90),
#  (None, 2, 90),
#  (None, 3, 90),
#  (None, 3, 90),
#  (None, 1, 91),
#  (None, 1, 91),
#  (None, 1, 91),
#  (None, 2, 91),
#  (None, 2, 92),
#  (None, 0, 92),
#  (None, 3, 92),
#  (None, 3, 92),
#  (None, 2, 93),
#  (None, 1, 93),
#  (None, 0, 93),
#  (None, 1, 93),
#  (None, 2, 94),
#  (None, 1, 94),
#  (None, 1, 94),
#  (None, 0, 94),
#  (None, 0, 95),
#  (None, 2, 95),
#  (None, 3, 95),
#  (None, 2, 95),
#  (None, 3, 96),
#  (None, 3, 96),
#  (None, 1, 96),
#  (None, 0, 96),
#  (None, 1, 97),
#  (None, 0, 97),
#  (None, 1, 97),
#  (None, 0, 97),
#  (None, 2, 98),
#  (None, 0, 98),
#  (None, 2, 98),
#  (None, 0, 98),
#  (None, 1, 99),
#  (None, 2, 99),
#  (None, 2, 99),
#  (None, 1, 99),
#  (None, 1, 100),
#  (None, 3, 100),
#  (None, 1, 100),
#  (None, 0, 100),
#  (None, 1, 101),
#  (None, 3, 101),
#  (None, 1, 101),
#  (None, 3, 101),
#  (None, 0, 102),
#  (None, 2, 102),
#  (None, 2, 102),
#  (None, 3, 102),
#  (None, 0, 103),
#  (None, 0, 103),
#  (None, 0, 103),
#  (None, 1, 103),
#  (None, 3, 104),
#  (None, 0, 104),
#  (None, 2, 104),
#  (None, 0, 104),
#  (None, 3, 105),
#  (None, 1, 105),
#  (None, 0, 105),
#  (None, 1, 105),
#  (None, 1, 106),
#  (None, 1, 106),
#  (None, 2, 106),
#  (None, 2, 106),
#  (None, 1, 107),
#  (None, 0, 107),
#  (None, 1, 107),
#  (None, 3, 107),
#  (None, 2, 108),
#  (None, 2, 108),
#  (None, 0, 108),
#  (None, 2, 108),
#  (None, 2, 109),
#  (None, 1, 109),
#  (None, 2, 109),
#  (None, 0, 109),
#  (None, 3, 110),
#  (None, 0, 110),
#  (None, 2, 110),
#  (None, 0, 110),
#  (None, 3, 111),
#  (None, 3, 111),
#  (None, 3, 111),
#  (None, 1, 111),
#  (None, 1, 112),
#  (None, 1, 112),
#  (None, 1, 112),
#  (None, 3, 112),
#  (None, 0, 113),
#  (None, 3, 113),
#  (None, 0, 113),
#  (None, 0, 113),
#  (None, 1, 114),
#  (None, 1, 114),
#  (None, 3, 114),
#  (None, 1, 114),
#  (None, 0, 115),
#  (None, 2, 115),
#  (None, 1, 115),
#  (None, 2, 115),
#  (None, 2, 116),
#  (None, 1, 116),
#  (None, 1, 116),
#  (None, 3, 116),
#  (None, 3, 117),
#  (None, 3, 117),
#  (None, 1, 117),
#  (None, 1, 117),
#  (None, 0, 118),
#  (None, 1, 118),
#  (None, 1, 118),
#  (None, 0, 118),
#  (None, 1, 119),
#  (None, 0, 119),
#  (None, 1, 119),
#  (None, 1, 119),
#  (None, 0, 120),
#  (None, 3, 120),
#  (None, 2, 120),
#  (None, 2, 120),
#  (None, 1, 121),
#  (None, 1, 121),
#  (None, 2, 121),
#  (None, 2, 121),
#  (None, 3, 122),
#  (None, 2, 122),
#  (None, 3, 122),
#  (None, 1, 122),
#  (None, 0, 123),
#  (None, 2, 123),
#  (None, 2, 123),
#  (None, 3, 123),
#  (None, 2, 124),
#  (None, 0, 124),
#  (None, 0, 124),
#  (None, 1, 124),
#  (None, 0, 125),
#  (None, 3, 125),
#  (None, 3, 125),
#  (None, 2, 125),
#  (None, 1, 126),
#  (None, 2, 126),
#  (None, 0, 126),
#  (None, 2, 126),
#  (None, 3, 127),
#  (None, 1, 127),
#  (None, 1, 127),
#  (None, 3, 127),
#  (None, 1, 128),
#  (None, 0, 128),
#  (None, 3, 128),
#  (None, 1, 128),
#  (None, 1, 129),
#  (None, 0, 129),
#  (None, 1, 129),
#  (None, 0, 129),
#  (None, 3, 130),
#  (None, 2, 130),
#  (None, 3, 130),
#  (None, 2, 130),
#  (None, 3, 131),
#  (None, 1, 131),
#  (None, 2, 131),
#  (None, 1, 131),
#  (None, 2, 132),
#  (None, 1, 132),
#  (None, 2, 132),
#  (None, 0, 132),
#  (None, 1, 133),
#  (None, 1, 133),
#  (None, 1, 133),
#  (None, 3, 133),
#  (None, 1, 134),
#  (None, 3, 134),
#  (None, 1, 134),
#  (None, 2, 134),
#  (None, 1, 135),
#  (None, 0, 135),
#  (None, 1, 135),
#  (None, 1, 135),
#  (None, 0, 136),
#  (None, 3, 136),
#  (None, 1, 136),
#  (None, 2, 136),
#  (None, 2, 137),
#  (None, 1, 137),
#  (None, 3, 137),
#  (None, 3, 138),
#  (None, 1, 138),
#  (None, 3, 138),
#  (None, 2, 139),
#  (None, 1, 139),
#  (None, 2, 139),
#  (None, 3, 140),
#  (None, 0, 140),
#  (None, 0, 140),
#  (None, 0, 141),
#  (None, 2, 141),
#  (None, 0, 141),
#  (None, 1, 142),
#  (None, 0, 142),
#  (None, 1, 142),
#  (None, 3, 143),
#  (None, 2, 143),
#  (None, 3, 143),
#  (None, 0, 144),
#  (None, 1, 144),
#  (None, 2, 144),
#  (None, 0, 145),
#  (None, 1, 145),
#  (None, 0, 145),
#  (None, 1, 146),
#  (None, 3, 146),
#  (None, 1, 146),
#  (None, 3, 147),
#  (None, 2, 147),
#  (None, 0, 147),
#  (None, 2, 148),
#  (None, 3, 148),
#  (None, 3, 148),
#  (None, 2, 149),
#  (None, 3, 149),
#  (None, 1, 149),
#  (None, 1, 150),
#  (None, 1, 150),
#  (None, 3, 150),
#  (None, 2, 151),
#  (None, 1, 151),
#  (None, 2, 151),
#  (None, 1, 152),
#  (None, 3, 152),
#  (None, 1, 152),
#  (None, 3, 153),
#  (None, 3, 153),
#  (None, 1, 153),
#  (None, 1, 154),
#  (None, 3, 154),
#  (None, 3, 154),
#  (None, 2, 155),
#  (None, 0, 155),
#  (None, 3, 155),
#  (None, 3, 156),
#  (None, 2, 156),
#  (None, 2, 156),
#  (None, 0, 157),
#  (None, 1, 157),
#  (None, 0, 157),
#  (None, 2, 158),
#  (None, 1, 158),
#  (None, 1, 158),
#  (None, 2, 159),
#  (None, 0, 159),
#  (None, 1, 159),
#  (None, 3, 160),
#  (None, 3, 160),
#  (None, 1, 160),
#  (None, 1, 161),
#  (None, 0, 161),
#  (None, 3, 161),
#  (None, 2, 162),
#  (None, 2, 162),
#  (None, 0, 162),
#  (None, 3, 163),
#  (None, 3, 163),
#  (None, 0, 163),
#  (None, 0, 164),
#  (None, 3, 164),
#  (None, 3, 164),
#  (None, 1, 165),
#  (None, 0, 165),
#  (None, 2, 165),
#  (None, 0, 166),
#  (None, 1, 166),
#  (None, 1, 166),
#  (None, 1, 167),
#  (None, 0, 167),
#  (None, 1, 167),
#  (None, 2, 168),
#  (None, 1, 168),
#  (None, 2, 168),
#  (None, 0, 169),
#  (None, 1, 169),
#  (None, 3, 169),
#  (None, 1, 170),
#  (None, 2, 170),
#  (None, 2, 170),
#  (None, 0, 171),
#  (None, 2, 171),
#  (None, 0, 171),
#  (None, 3, 172),
#  (None, 0, 172),
#  (None, 3, 172),
#  (None, 1, 173),
#  (None, 1, 173),
#  (None, 0, 173),
#  (None, 3, 174),
#  (None, 3, 174),
#  (None, 1, 174),
#  (None, 2, 175),
#  (None, 0, 175),
#  (None, 0, 175),
#  (None, 1, 176),
#  (None, 3, 176),
#  (None, 1, 176),
#  (None, 2, 177),
#  (None, 1, 177),
#  (None, 3, 177),
#  (None, 3, 178),
#  (None, 2, 178),
#  (None, 1, 178),
#  (None, 3, 179),
#  (None, 2, 179),
#  (None, 1, 179),
#  (None, 1, 180),
#  (None, 1, 180),
#  (None, 1, 180),
#  (None, 2, 181),
#  (None, 1, 181),
#  (None, 1, 181),
#  (None, 0, 182),
#  (None, 2, 182),
#  (None, 0, 182),
#  (None, 1, 183),
#  (None, 0, 183),
#  (None, 2, 183),
#  (None, 2, 184),
#  (None, 0, 184),
#  (None, 0, 184),
#  (None, 0, 185),
#  (None, 0, 185),
#  (None, 3, 185),
#  (None, 1, 186),
#  (None, 1, 186),
#  (None, 0, 186),
#  (None, 1, 187),
#  (None, 3, 187),
#  (None, 0, 187),
#  (None, 3, 188),
#  (None, 3, 188),
#  (None, 2, 188),
#  (None, 0, 189),
#  (None, 0, 189),
#  (None, 3, 189),
#  (None, 3, 190),
#  (None, 1, 190),
#  (None, 1, 190),
#  (None, 2, 191),
#  (None, 0, 191),
#  (None, 2, 191),
#  (None, 0, 192),
#  (None, 2, 192),
#  (None, 2, 192),
#  (None, 3, 193),
#  (None, 3, 193),
#  (None, 3, 193),
#  (None, 2, 194),
#  (None, 2, 194),
#  (None, 3, 194),
#  (None, 0, 195),
#  (None, 2, 195),
#  (None, 1, 195),
#  (None, 1, 196),
#  (None, 2, 196),
#  (None, 1, 196),
#  (None, 2, 197),
#  (None, 1, 197),
#  (None, 1, 197),
#  (None, 1, 198),
#  (None, 0, 198),
#  (None, 1, 198),
#  (None, 0, 199),
#  (None, 1, 199),
#  (None, 2, 199),
#  (None, 2, 200),
#  (None, 2, 200),
#  (None, 1, 200),
#  (None, 1, 201),
#  (None, 3, 201),
#  (None, 1, 201),
#  (None, 3, 202),
#  (None, 1, 202),
#  (None, 0, 202),
#  (None, 1, 203),
#  (None, 1, 203),
#  (None, 0, 203),
#  (None, 1, 204),
#  (None, 0, 204),
#  (None, 0, 204),
#  (None, 3, 205),
#  (None, 3, 205),
#  (None, 3, 205),
#  (None, 1, 206),
#  (None, 0, 206),
#  (None, 0, 206),
#  (None, 0, 207),
#  (None, 0, 207),
#  (None, 1, 207),
#  (None, 1, 208),
#  (None, 2, 208),
#  (None, 2, 208),
#  (None, 0, 209),
#  (None, 2, 209),
#  (None, 3, 209),
#  (None, 1, 210),
#  (None, 3, 210),
#  (None, 1, 210),
#  (None, 0, 211),
#  (None, 1, 211),
#  (None, 1, 211),
#  (None, 0, 212),
#  (None, 1, 212),
#  (None, 2, 212),
#  (None, 1, 213),
#  (None, 1, 213),
#  (None, 0, 213),
#  (None, 2, 214),
#  (None, 2, 214),
#  (None, 3, 214),
#  (None, 2, 215),
#  (None, 1, 215),
#  (None, 3, 215),
#  (None, 3, 216),
#  (None, 0, 216),
#  (None, 2, 216),
#  (None, 3, 217),
#  (None, 2, 217),
#  (None, 3, 217),
#  (None, 1, 218),
#  (None, 0, 218),
#  (None, 3, 218),
#  (None, 0, 219),
#  (None, 1, 219),
#  (None, 0, 219),
#  (None, 1, 220),
#  (None, 3, 220),
#  (None, 1, 220),
#  (None, 0, 221),
#  (None, 1, 221),
#  (None, 1, 221),
#  (None, 3, 222),
#  (None, 1, 222),
#  (None, 1, 222),
#  (None, 3, 223),
#  (None, 0, 223),
#  (None, 1, 223),
#  (None, 0, 224),
#  (None, 3, 224),
#  (None, 2, 224),
#  (None, 1, 225),
#  (None, 2, 225),
#  (None, 2, 225),
#  (None, 1, 226),
#  (None, 1, 226),
#  (None, 0, 226),
#  (None, 3, 227),
#  (None, 2, 227),
#  (None, 0, 227),
#  (None, 0, 228),
#  (None, 2, 228),
#  (None, 2, 228),
#  (None, 1, 229),
#  (None, 0, 229),
#  (None, 0, 229),
#  (None, 2, 230),
#  (None, 0, 230),
#  (None, 1, 230),
#  (None, 2, 231),
#  (None, 1, 231),
#  (None, 1, 231),
#  (None, 0, 232),
#  (None, 1, 232),
#  (None, 1, 232),
#  (None, 1, 233),
#  (None, 2, 233),
#  (None, 3, 233),
#  (None, 1, 234),
#  (None, 3, 234),
#  (None, 2, 234),
#  (None, 1, 235),
#  (None, 2, 235),
#  (None, 3, 235),
#  (None, 1, 236),
#  (None, 1, 236),
#  (None, 2, 236),
#  (None, 3, 237),
#  (None, 3, 237),
#  (None, 3, 237),
#  (None, 0, 238),
#  (None, 2, 238),
#  (None, 1, 238),
#  (None, 2, 239),
#  (None, 0, 239),
#  (None, 1, 239),
#  (None, 2, 240),
#  (None, 1, 240),
#  (None, 1, 240),
#  (None, 1, 241),
#  (None, 2, 241),
#  (None, 2, 241),
#  (None, 3, 242),
#  (None, 3, 242),
#  (None, 0, 242),
#  (None, 0, 243),
#  (None, 0, 243),
#  (None, 0, 243),
#  (None, 1, 244),
#  (None, 2, 244),
#  (None, 1, 244),
#  (None, 3, 245),
#  (None, 2, 245),
#  (None, 3, 245),
#  (None, 2, 246),
#  (None, 2, 246),
#  (None, 3, 246),
#  (None, 1, 247),
#  (None, 1, 247),
#  (None, 1, 247),
#  (None, 1, 248),
#  (None, 1, 248),
#  (None, 2, 248),
#  (None, 0, 249),
#  (None, 2, 249),
#  (None, 2, 249),
#  (None, 1, 250),
#  (None, 2, 250),
#  (None, 3, 250),
#  (None, 0, 251),
#  (None, 1, 251),
#  (None, 1, 251),
#  (None, 2, 252),
#  (None, 1, 252),
#  (None, 2, 252),
#  (None, 2, 253),
#  (None, 0, 253),
#  (None, 0, 253),
#  (None, 1, 254),
#  (None, 1, 254),
#  (None, 0, 254),
#  (None, 1, 255),
#  (None, 2, 255),
#  (None, 1, 255),
#  (None, 3, 256),
#  (None, 1, 256),
#  (None, 2, 256),
#  (None, 3, 257),
#  (None, 0, 257),
#  (None, 2, 257),
#  (None, 1, 258),
#  (None, 0, 258),
#  (None, 1, 258),
#  (None, 1, 259),
#  (None, 3, 259),
#  (None, 3, 259),
#  (None, 0, 260),
#  (None, 1, 260),
#  (None, 1, 260),
#  (None, 0, 261),
#  (None, 1, 261),
#  (None, 3, 261),
#  (None, 3, 262),
#  (None, 0, 262),
#  (None, 0, 262),
#  (None, 2, 263),
#  (None, 1, 263),
#  (None, 1, 263),
#  (None, 2, 264),
#  (None, 3, 264),
#  (None, 2, 264),
#  (None, 0, 265),
#  (None, 0, 265),
#  (None, 0, 265),
#  (None, 0, 266),
#  (None, 3, 266),
#  (None, 0, 266),
#  (None, 2, 267),
#  (None, 2, 267),
#  (None, 1, 267),
#  (None, 1, 268),
#  (None, 3, 268),
#  (None, 0, 268),
#  (None, 0, 269),
#  (None, 2, 269),
#  (None, 3, 269),
#  (None, 1, 270),
#  (None, 1, 270),
#  (None, 3, 270),
#  (None, 1, 271),
#  (None, 2, 271),
#  (None, 2, 271),
#  (None, 1, 272),
#  (None, 1, 272),
#  (None, 3, 272),
#  (None, 3, 273),
#  (None, 0, 273),
#  (None, 1, 273),
#  (None, 3, 274),
#  (None, 3, 274),
#  (None, 3, 274),
#  (None, 1, 275),
#  (None, 3, 275),
#  (None, 0, 275),
#  (None, 0, 276),
#  (None, 3, 276),
#  (None, 1, 276),
#  (None, 0, 277),
#  (None, 0, 277),
#  (None, 2, 277),
#  (None, 2, 278),
#  (None, 1, 278),
#  (None, 3, 278),
#  (None, 3, 279),
#  (None, 1, 279),
#  (None, 1, 279),
#  (None, 1, 280),
#  (None, 3, 280),
#  (None, 1, 280),
#  (None, 1, 281),
#  (None, 2, 281),
#  (None, 0, 281),
#  (None, 0, 282),
#  (None, 1, 282),
#  (None, 3, 282),
#  (None, 1, 283),
#  (None, 2, 283),
#  (None, 0, 283),
#  (None, 2, 284),
#  (None, 0, 284),
#  (None, 0, 284),
#  (None, 0, 285),
#  (None, 1, 285),
#  (None, 1, 285),
#  (None, 1, 286),
#  (None, 1, 286),
#  (None, 2, 286),
#  (None, 1, 287),
#  (None, 1, 287),
#  (None, 2, 287),
#  (None, 3, 288),
#  (None, 2, 288),
#  (None, 0, 288),
#  (None, 3, 289),
#  (None, 1, 289),
#  (None, 0, 289),
#  (None, 0, 290),
#  (None, 1, 290),
#  (None, 1, 290),
#  (None, 1, 291),
#  (None, 0, 291),
#  (None, 2, 291),
#  (None, 2, 292),
#  (None, 0, 292),
#  (None, 3, 292),
#  (None, 2, 293),
#  (None, 3, 293),
#  (None, 2, 293),
#  (None, 3, 294),
#  (None, 1, 294),
#  (None, 1, 294),
#  (None, 1, 295),
#  (None, 3, 295),
#  (None, 3, 295),
#  (None, 0, 296),
#  (None, 2, 296),
#  (None, 3, 296),
#  (None, 3, 297),
#  (None, 3, 297),
#  (None, 1, 297),
#  (None, 1, 298),
#  (None, 0, 298),
#  (None, 1, 298),
#  (None, 2, 299),
#  (None, 1, 299),
#  (None, 3, 299),
#  (None, 2, 300),
#  (None, 2, 300),
#  (None, 3, 300),
#  (None, 0, 301),
#  (None, 3, 301),
#  (None, 2, 301),
#  (None, 3, 302),
#  ...]
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 2
# top of loop for 2
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 3
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 2
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 2
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 0
# top of loop for 3
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 2
# top of loop for 2
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 2
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 0
# top of loop for 3
# top of loop for 3
# top of loop for 2
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 2
# top of loop for 2
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 0
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 0
# top of loop for 3
# top of loop for 3
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 2
# top of loop for 2
# top of loop for 0
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 2
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 3
# top of loop for 2
# top of loop for 2
# top of loop for 3
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 3
# top of loop for 0
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 2
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 2
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 3
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 3
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 2
# top of loop for 0
# top of loop for 2
# top of loop for 3
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 3
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 2
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 2
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 0
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 3
# top of loop for 3
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 2
# top of loop for 0
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 2
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 3
# top of loop for 3
# top of loop for 2
# top of loop for 2
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 0
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 0
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 2
# top of loop for 2
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 2
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 3
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 3
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 2
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 0
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 2
# top of loop for 2
# top of loop for 2
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 1
# top of loop for 3
# top of loop for 3
# top of loop for 2
# top of loop for 2
# top of loop for 2
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 0
# top of loop for 1
# top of loop for 2
# top of loop for 3
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 3
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 3
# top of loop for 3
# top of loop for 3
# top of loop for 2
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 2
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 1
# top of loop for 2
# top of loop for 1
# top of loop for 2
# top of loop for 0
# top of loop for 3
# top of loop for 1
# top of loop for 0
# top of loop for 1
# top of loop for 0
# top of loop for 3
# top of loop for 2
# top of loop for 0
# top of loop for 1
# top of loop for 1
# top of loop for 1
# top of loop for 3
# top of loop for 1

# %%
import sqlite3, os

# os.remove("foo.db")
db = sqlite3.connect("foo.db")
db.execute("CREATE TABLE foo (id INT, count TEXT)")
db.execute("INSERT INTO foo (count) values (:count)", {"count": 14688121314846993587})

db.execute("select * from foo order by count").fetchall()
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-18-f156101026ee> in <module>
#       4 db = sqlite3.connect("foo.db")
#       5 db.execute("CREATE TABLE foo (id INT, count TEXT)")
# ----> 6 db.execute("INSERT INTO foo (count) values (:count)", {"count": 14688121314846993587})
#       7
#       8 db.execute("select * from foo order by count").fetchall()
#
# OverflowError: Python int too large to convert to SQLite INTEGER

# %%
14688121314846993587 < 9223372036854775807
# Out:
# False

# %%
(14688121314846993587).to_bytes(8, 'little')
# Out:
# b'\xb3lL\xcd\x83\xb0\xd6\xcb'
